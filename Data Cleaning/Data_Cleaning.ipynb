# %%
import pandas as pd 
df = pd.read_excel("Customer Call List.xlsx")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.drop_duplicates().head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter    /White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    Not_Useful_Column
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True

# %%
df.drop(columns= 'Not_Useful_Column').head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter    /White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No

# %%
df['Last_Name'] = df['Last_Name'].str.strip(".../_123")
df.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter     White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    Not_Useful_Column
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True

# %%
is_replaced = df["First_Name"].str.replace('Anakin','')
is_replaced
# Out:
# 0        Frodo
# 1         Abed
# 2       Walter
# 3       Dwight
# 4          Jon
# 5          Ron
# 6         Jeff
# 7     Sherlock
# 8      Gandalf
# 9        Peter
# 10     Samwise
# 11       Harry
# 12         Don
# 13      Leslie
# 14        Toby
# 15         Ron
# 16    Michael
# 17       Clark
# 18       Creed
# 19
# 20
# Name: First_Name, dtype: object

# %%
df['Phone_Number'].replace(value = '', to_replace = '[^a-zA-Z0-9]', regex = True)
# Out:
# 0     1235455421
# 1     1236439775
# 2     7066950392
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6            NaN
# 7     8766783469
# 8             Na
# 9     1235455421
# 10           NaN
# 11    7066950392
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17    7066950392
# 18            Na
# 19    8766783469
# 20    8766783469
# Name: Phone_Number, dtype: object

# %%
df.head(2)
# Out:
#    CustomerID First_Name Last_Name  Phone_Number                Address  \
# 0        1001      Frodo   Baggins  123-545-5421  123 Shire Lane, Shire
# 1        1002       Abed     Nadir  123/643/9775    93 West Main Street
#
#   Paying Customer Do_Not_Contact  Not_Useful_Column
# 0             Yes             No               True
# 1              No            Yes              False

# %%
df['Phone_Number'] = df['Phone_Number'].replace(value = '', to_replace = '[^a-zA-Z0-9]', regex = True)
df.head(3)
# Out:
#    CustomerID First_Name Last_Name Phone_Number                Address  \
# 0        1001      Frodo   Baggins   1235455421  123 Shire Lane, Shire
# 1        1002       Abed     Nadir   1236439775    93 West Main Street
# 2        1003     Walter     White   7066950392     298 Drugs Driveway
#
#   Paying Customer Do_Not_Contact  Not_Useful_Column
# 0             Yes             No               True
# 1              No            Yes              False
# 2               N            NaN               True

# %%
df['Phone_Number'] = df['Phone_Number'].apply(lambda x: str(x))
df['Phone_Number'].apply(lambda x: x[0:3] + '--SuDip--' + x[3:6] + '--SuDip--' + x[6:9]).head()
# Out:
# 0    123--SuDip--545--SuDip--542
# 1    123--SuDip--643--SuDip--977
# 2    706--SuDip--695--SuDip--039
# 3    123--SuDip--543--SuDip--234
# 4    876--SuDip--678--SuDip--346
# Name: Phone_Number, dtype: object

# %%
df['Phone_Number'] = df['Phone_Number'].apply(lambda x: x[0:3] + '' + x[3:6] + '' + x[6:9])
df["Phone_Number"].head()
# Out:
# 0    123545542
# 1    123643977
# 2    706695039
# 3    123543234
# 4    876678346
# Name: Phone_Number, dtype: object

# %%
df.loc[df['First_Name'] == 'Gandalf']
# Out:
#    CustomerID First_Name Last_Name Phone_Number           Address  \
# 8        1009    Gandalf       NaN           Na  123 Middle Earth
#
#   Paying Customer Do_Not_Contact  Not_Useful_Column
# 8             Yes            NaN              False

# %%
# df["Phone_Number"] = df['Phone_Number'].replace(to_replace = 'N/a',value = '')
# df["Phone_Number"] = df['Phone_Number'].replace(to_replace = 'nan',value = '')
# df["Phone_Number"] = df['Phone_Number'].replace(to_replace = 'Na',value = '')
# df['Phone_Number']

# %%
df.shape
# Out:
# (21, 8)

# %% [markdown]
# ### Changing Yes/No to Y/N

# %%
df["Paying Customer"] =df["Paying Customer"].str.replace('Yes','Y')
df["Paying Customer"] =df["Paying Customer"].str.replace('No','N')
df["Do_Not_Contact"] =df["Do_Not_Contact"].str.replace('Yes','Y')
df["Do_Not_Contact"] =df["Do_Not_Contact"].str.replace('No','N')
df.head()
# Out:
#    CustomerID First_Name Last_Name Phone_Number  \
# 0        1001      Frodo   Baggins    123545542
# 1        1002       Abed     Nadir    123643977
# 2        1003     Walter     White    706695039
# 3        1004     Dwight   Schrute    123543234
# 4        1005        Jon      Snow    876678346
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire               Y              N
# 1                    93 West Main Street               N              Y
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503               Y              Y
# 4                       123 Dragons Road               Y              N
#
#    Not_Useful_Column
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True

# %% [markdown]
# ### Dropping all the empty cells
# ```df.dropna(*, axis=0, how=_NoDefault.no_default, thresh=_NoDefault.no_default, subset=None, inplace=False, ignore_index=False)```

# %%
# df.dropna(axis = 1)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins    123545542
# 1         1002       Abed       Nadir    123643977
# 2         1003     Walter       White    706695039
# 3         1004     Dwight     Schrute    123543234
# 4         1005        Jon        Snow    876678346
# 5         1006        Ron     Swanson    304762246
# 6         1007       Jeff      Winger          nan
# 7         1008   Sherlock      Holmes    876678346
# 8         1009    Gandalf         NaN           Na
# 9         1010      Peter      Parker    123545542
# 10        1011    Samwise      Gamgee          nan
# 11        1012      Harry      Potter    706695039
# 12        1013        Don      Draper    123543234
# 13        1014     Leslie       Knope    876678346
# 14        1015       Toby  Flenderson    304762246
# 15        1016        Ron     Weasley    123545542
# 16        1017   Michael        Scott    123643977
# ...

# %%
df.dropna(how = "all")
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins    123545542
# 1         1002       Abed       Nadir    123643977
# 2         1003     Walter       White    706695039
# 3         1004     Dwight     Schrute    123543234
# 4         1005        Jon        Snow    876678346
# 5         1006        Ron     Swanson    304762246
# 6         1007       Jeff      Winger          nan
# 7         1008   Sherlock      Holmes    876678346
# 8         1009    Gandalf         NaN           Na
# 9         1010      Peter      Parker    123545542
# 10        1011    Samwise      Gamgee          nan
# 11        1012      Harry      Potter    706695039
# 12        1013        Don      Draper    123543234
# 13        1014     Leslie       Knope    876678346
# 14        1015       Toby  Flenderson    304762246
# 15        1016        Ron     Weasley    123545542
# 16        1017   Michael        Scott    123643977
# ...

# %%
df.shape
# Out:
# (21, 8)

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# First_Name           0
# Last_Name            1
# Phone_Number         0
# Address              0
# Paying Customer      0
# Do_Not_Contact       4
# Not_Useful_Column    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# First_Name           0
# Last_Name            0
# Phone_Number         0
# Address              0
# Paying Customer      0
# Do_Not_Contact       0
# Not_Useful_Column    0
# dtype: int64

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins    123545542
# 1         1002       Abed       Nadir    123643977
# 3         1004     Dwight     Schrute    123543234
# 4         1005        Jon        Snow    876678346
# 5         1006        Ron     Swanson    304762246
# 6         1007       Jeff      Winger          nan
# 7         1008   Sherlock      Holmes    876678346
# 9         1010      Peter      Parker    123545542
# 10        1011    Samwise      Gamgee          nan
# 12        1013        Don      Draper    123543234
# 13        1014     Leslie       Knope    876678346
# 14        1015       Toby  Flenderson    304762246
# 15        1016        Ron     Weasley    123545542
# 16        1017   Michael        Scott    123643977
# 18        1019      Creed      Braton           Na
# 19        1020     Anakin   Skywalker    876678346
# 20        1020     Anakin   Skywalker    876678346
#
# ...

# %%
df["Phone_Number"].replace(['nan','Na'], None,inplace=True)

# %%
df["Address"].replace('N/a',None,inplace=True)

# %%
df["Paying Customer"].replace('N/a',None,inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (14, 8)

# %%
df1 = df

# %%
df1.reset_index(drop=True,inplace=True)

# %%
df1
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins    123545542
# 1         1002       Abed       Nadir    123643977
# 2         1004     Dwight     Schrute    123543234
# 3         1005        Jon        Snow    876678346
# 4         1006        Ron     Swanson    304762246
# 5         1008   Sherlock      Holmes    876678346
# 6         1010      Peter      Parker    123545542
# 7         1013        Don      Draper    123543234
# 8         1014     Leslie       Knope    876678346
# 9         1015       Toby  Flenderson    304762246
# 10        1016        Ron     Weasley    123545542
# 11        1017   Michael        Scott    123643977
# 12        1020     Anakin   Skywalker    876678346
# 13        1020     Anakin   Skywalker    876678346
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire               Y              N
# ...

# %%
df1[['Address','State', 'Zip_Code']] = df1['Address'].str.split(',',n= 2, expand=True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number               Address  \
# 0         1001      Frodo     Baggins    123545542        123 Shire Lane
# 1         1002       Abed       Nadir    123643977   93 West Main Street
# 2         1004     Dwight     Schrute    123543234      980 Paper Avenue
# 3         1005        Jon        Snow    876678346      123 Dragons Road
# 4         1006        Ron     Swanson    304762246      768 City Parkway
# 5         1008   Sherlock      Holmes    876678346         98 Clue Drive
# 6         1010      Peter      Parker    123545542      25th Main Street
# 7         1013        Don      Draper    123543234      2039 Main Street
# 8         1014     Leslie       Knope    876678346      343 City Parkway
# 9         1015       Toby  Flenderson    304762246         214 HR Avenue
# 10        1016        Ron     Weasley    123545542  2395 Hogwarts Avenue
# 11        1017   Michael        Scott    123643977      121 Paper Avenue
# ...
